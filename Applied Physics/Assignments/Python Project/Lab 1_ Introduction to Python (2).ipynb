# %% [markdown]
# # Introduction to Python
# ### **Applied Physics Lab**
#
#
# ***
#
# $\color{red}{\text{This introductory tutorial is designed to introduce freshman to python for the purpose of use in Applied Physics simmulation lab. This introduction includes material from tutorials developed by Mark Bakker for TUDelft}}$

# %% [markdown]
# ***
#
# **Python** is a general purpose high level programming lagnguage, designed by Guido van Rossum in 1991. Python has several advantages over other programming languages. such as
# * Code readability
# * Easy syntax
# * English like keywords
# * Concise programs
# * Free and open source software
#
# **The Jupyter Notebook** is an open-source web application that allows us to create and share documents that contain live code, equations, visualizations and narrative text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, data visualization, machine learning, and much more. So in summary Jupyter notebook is *A single document that combines explanations with executable code and its output*
#
# **Colaboratory**, or “**Colab**” for short, is a product from Google Research. Colab allows anybody to write and execute arbitrary python code through the browser, and is especially well suited to machine learning, data analysis and education.
#
# <hr>
#
# Following are some objects that you will most probably encounter in every computer languages so these hints are here to guide you in the start.
# - **Integers**: numbers without decimal
# - **Floats**: numbers with decimal values
# - **Strings**: those that can not be computed, these are just names. They are formed using quotes `" "` made out of alphabatic, special and numerical characters mixed.
# - **Variables**: Objects that can store values and other objects. Variables can not be number. Variables be called by their names and must be composed of single string, i.e. no spacing allowed. `My_ambitions` is allowed but `My ambitions` is not. Variables are case sensitive too.
# - **Functions**:
#     * **predefined**: These are reserved for the use of the language, you can use them but you can't name anything same as these. examples: `print`, `for`
#     * **user defined**: You can make your own functions which will be stored for your later use.
# - **Booleans**: `True` and `False`, they are also interpreted as `1` and `0`, respectively.
# - **Conditions**: Logic conditions may be used via following symbols; \
# is equal to $\Longrightarrow$ `==`\
# is not equal to $\Longrightarrow$ `!=`\
# is greater than $\Longrightarrow$ `>` etc
#
#
# <hr>

# %% [markdown]
# ## Content
#
# * Basic operations
# * Lists
# * Plotting
# * Loops (for and while)
# * if/else condition
# * Functions

# %% [markdown]
# ### Basic Operations
#
# "Portable, powerful, and a breeze to use", Python is a popular, open-source programming language used for both scripting applications and standalone programs (see "Learning Python" by Mark Lutz). Python can be used to do pretty much anything. For example, you can use Python as a calculator. Position your cursor in the code cell below and hit `[shift][enter]`. The output should be 12

# %%
6 * 2

# %% [markdown]
# Note that the extra spaces are added to make the code more readable. 2 * 3 works just as well as 2*3. And it is considered good style. Use the extra spaces in all your Notebooks.
#
# When you are programming, you want to store your values in variables

# %%
a = 6
b = 2

a * b

# %% [markdown]
# Both a and b are now variables. Each variable has a type. In this case, they are both integers (whole numbers). To write the value of a variable to the screen, use the `print()` function (the last value stored in a variable is printed). Note that multiplication of two integers results in an integer, but division of two integers results in a float (a number with decimal places).

# %%
print(a)
print(b)
print(a * b)
print(a / b)

# %% [markdown]
# You can add some text to the print function by putting the text string between quotes (either single or double quotes work as long as you use the same at the beginning and end), and separate the text string and the variable by a comma

# %%
print('the value of a is', a)

# %% [markdown]
# A variable can be raised to a power by using ** (a hat ^, as used in some other languages, doesn't work).

# %%
a ** b

# %% [markdown]
# **Exercise 1a-i, Polynomial**
#
# Compute the value of the polynomial $y=ax^2+bx+c$ at $x=−2$ using $a=1$, $b=1$, $c=−6$ and print the result to the screen.

# %%
# your answer here

# %% [markdown]
# **Exercise 1a-ii, Polynomial**
#
# Now compute the value of the polynomial $y=ax^2+bx+c$ at $x=−2$, $x=0$, and $x=2.1$ using $a=1$, $b=1$, $c=−6$ and print the results to the screen.

# %%
# your answer here

# %% [markdown]
# **Division**
#
# Division works just as well...

# %%
print('1/3 gives', a / 3)

# %% [markdown]
# ### Lists
#
# List, as the name implies are lists of variables, numbers or even lists as well. These lists of lists are what we normally call matrices. The list has a name and all the objects in lists are indexed i.e. they are identified by there unique position in a list starting from zero. So a list with 18 elements will have index from 0-17. Lets create a list called "even" containing some even numbers

# %%
even = [2,4,8,6,14]

# %%
# lists can also be called directly by their name
even

# %% [markdown]
# but if we want some element form this list we can simply name the list with index in [ ] in front, like this...

# %%
print(even[0])
print(even[1])
print(even[2])
print(even[3])
print('length of the list is',len(even))

# %%
# Guess the result of the following command
print(even[4]*even[0])

# %% [markdown]
# ### Plotting
#
# Plotting is not part of standard Python, but a nice package exists to create pretty graphics (and ugly ones, if you want). A package is a library of functions for a specific set of tasks. The graphics package we use is called `matplotlib`. To be able to use the plotting functions in `matplotlib`, we have to import it. We import the plotting part of `matplotlib` and call it `plt`. Before we import `matplotlib`, we tell the Jupyter Notebook to show any graphs inside this Notebook and not in a separate window using the `%matplotlib inline` command (more on these commands later).

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Packages only have to be imported once in a Python session. After the above import statement, any plotting function may be called from any code cell as `plt.function`. For example

# %%
plt.plot([1, 2, 4, 'four', 2])

# %% [markdown]
# Let's try to plot $y$ vs $x$ for $x$ going from $−4$ to $+4$ for the polynomial $y=ax^2+bx+c$ with $a=1$, $b=1$, $c=−6$. To do this, we need to evaluate $y$ at a bunch of points. A sequence of values of the same type is called an array (for example an array of integers or floats). Array functionality is available in the package `numpy`. Let's import `numpy` and call it `np`, so that any function in the `numpy` package may be called as `np.function`.

# %%
import numpy as np

# %% [markdown]
# To create an array `x` consisting of, for example, 5 equally spaced points between `-4` and `4`, use the `linspace` command

# %%
x = np.linspace(-4, 4, 6)
print(x)
# Out:
# [-4.  -2.4 -0.8  0.8  2.4  4. ]

# %% [markdown]
# In the above cell, `x` is an array of 5 floats (`-4.` is a float, `-4` is an integer). If you type `np.linspace` and then an opening parenthesis like:
#
# `np.linspace(`
#
# and then hit [shift-tab] a little help box pops up to explain the input arguments of the function. When you click on the + sign, you can scroll through all the documentation of the linspace function. Click on the $x$ sign to remove the help box. Let's plot $y$ using 100 $x$ values from $−4$ to $+4$.

# %%
a = 1
b = 1
c = -6
x = np.linspace(-4, 4, 100)
y = a * x ** 2 + b * x + c  # Compute y for all x values
plt.plot(x, y)

# %% [markdown]
# Note that one hundred `y` values are computed in the simple line `y = a * x ** 2 + b * x + c`. Don't believe it? well then simply add a new code block above and call on `y` to see all the values for yourself.\
# Python treats arrays in the same fashion as it treats regular variables when you perform mathematical operations. The math is simply applied to every value in the array (and it runs much faster than when you would do every calculation separately).
#
# The plots can be overlapped providing important insight into comparison different behaviors in many studies. You can simply write another `plt.plot(x,  )` function with new `y` variable.

# %% [markdown]
# **Exerise 1b**
#
# Repeat above polynomial plotting with addition to generating an overlapping plot with extra polynomial `y1 = 2 * a * x ** 2 + b * x + c`. Use twice the function `plt.plot( , )` with correct arguments.

# %%
# your answer here

# %% [markdown]
# ### Assignments
#
# Computer languages has a counter intuitive way of writting an assignment operation, because it is denoted by `=` sign students often get confused by what it actually means. Using `=` operation statements like `i = i + 1` can exist. Because `=` sign actually means *assign the value on right to the variable on left*.
#
# let see how this method works,

# %%
a = a + 1

# %% [markdown]
# run the above cell again and again and see the output value increase by 1 on each run(of course it can increase or decrease by any value you like)

# %% [markdown]
# ### The loops, `for` and `while`
#
# Loops are used to execute a command repeatedly. The syntax for a loop is as follows

# %%
for i in [0, 1, 2, 3, 4]:
    print('Hello world, the value of i is', i)

# %% [markdown]
# In the code above, the variable `i` loops through the five values in the list `[0, 1, 2, 3, 4]`. The first time through, the value of `i` is equal to 0, the second time through, its value is `1`, and so on till the last time when its value is `4`. \
# Note the syntax of a for loop: At the end of the for statement you need to put a colon (`:`) and after that you need to indent. It doesn't matter how many spaces you indent, as long as you keep using the same number of spaces for the entire for loop. Jupyter Notebooks automatically indent `4` spaces, which is considered good Python style, so use that. You can have as many lines of code inside the `for` loop as you want. To end the `for` loop, simply stop indenting.

# %% [markdown]
# **Exercise 1c**
#
# repeat the above `for` loop but this time use the list [2,34,8,3]

# %%
# your answer here

# %%
for x in [0, 1, 2, 3]: 
    xsquared = x ** 2
    print('x', x, ' => xsquare', xsquared)
print('this print command will run when above for loop ends')

# %% [markdown]
# **Exercise 1d**
#
# Generate a multiplication table of any number in common format.

# %%
# 2 x 1 = 2
# your answer here

# %% [markdown]
# The list of values to loop through can be anything. It doesn't even have to be numbers. The `for` loop simply goes through all the values in the list one by one:

# %%
for data in [20, 'mark', np.sqrt(25)]:
    print('the value of data is:', data)

# %% [markdown]
# It is, of course, rather inconvenient to have to specify a list to loop through when the list is very long. For example, if you want to do something 100 times, you don't want to type a list of values from 0 up to 100. But Python has a convenient function for that called `range`. You can loop through a `range` just like you can loop through a list. To loop 10 times, starting with the value `0`:

# %%
for i in range(10):
    print('the value of i is:', i)

# %% [markdown]
# A `range` can be converted to a list with the `list` function. You can call `range` with just one argument, in which case it will generate a range from 0 up to but not including the specified number. Note that `range(10)` produces 10 numbers from 0 up to and including 9. You can optionally give a starting value and a step.

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 3 * np.pi, 100)
y = np.zeros_like(x)  # similar to x but with all items 0
for i in range(len(x)):
    y[i] = np.cos(x[i])
plt.plot(x, y);

# %% [markdown]
# **Class Shout-out Challenge**
# In a new code cell try to create the same graph but without using the `for` loop.\
# *Shout (decently) "Eureka" if you are the first one in class to solve this challenge.*

# %% [markdown]
# **Exercise 1e**
#
# Create a list with the names of the months. Create a second list with the total number of days in each month (for a regular year). Create a for loop that prints:
#
# `The number of days in MONTH is XX days`
#
# where, of course, you print the correct name of the month for MONTH and the correct number of days for XX.

# %%
# your answer here

# %% [markdown]
# For running loops with specified condition, a more useful looping tools in `while`. It works exaclty as it sounds i.e. the loop will only run *while* the stated condition is met. Here's an example,

# %%
t = 9
while t>=3:
    t = t - 1
    print('1 subtracted from ',t+1,'=',t)
print('the last value of t is ',t)

# %% [markdown]
# what should be the result of the following code,

# %%
# guess the result first

i,t = 0,0  # double assignment
while i<=100:
    i = i + 1
    t = t + i
print(t)

# %% [markdown]
# **Challenge yourself** alter the above while loop to print the value of $t$ in each iteration as well.

# %% [markdown]
# ### The `if`/`else` statement
#
# The `if` statement may be followed by an `else` statement, which is executed when the condition after `if` is False. For example

# %%
a = 4
if a < 3:
    print('a is smaller than 3')
else:
    print('a is not smaller than 3')

# %% [markdown]
# You can even extend the `else` by adding one or more conditions with the `elif` command which is short for 'else if'

# %%
a = 4
if a < 4:
    print('a is smaller than 4')
elif a > 4:
    print('a is larger than 4')
else:
    print('a is equal to 4')

# %% [markdown]
# Rather than specifying the value of a variable at the top of the code cell, you can ask the user to enter a value and store that value in the variable using the `input` function. The `input` function returns a string that can be converted into a number with the `float` function. Run the code cell below and test that it works when the entered value is larger than 4, smaller than 4, or equal to 4.

# %%
for i in range(3):       # do this 3 times
    a = float(input('Enter a value: '))
    if a < 4:
        print('the entered value is smaller than 4')
    elif a > 4:
        print('the entered value is larger than 4')
    else:
        print('the entered value is equal to 4')
# Out:
# Enter a value: 78
# the entered value is larger than 4
# Enter a value: 34
# the entered value is larger than 4
# Enter a value: 2
# the entered value is smaller than 4

# %% [markdown]
# An easy way to check multiple conditions is...

# %%
if (a+2==6, a+3==7, a!=0):
    print ('yes, a is 4')
else:
    print ('a is not', a)

# %% [markdown]
# **Exercise 1f. Combination of `for` loop with `if` statement**
#
# Consider the function
#
# $y=cos(x) \quad for  \quad   x<0$
#
# $y=exp(−x) \quad for \quad   x≥0$
#
# Compute $y$ for $x$ going from $−2π$ to $2π$ with 100 points and make a graph.

# %%
# your answer here

# %% [markdown]
# ### Functions
#
# Functions are an essential part of a programming language. You already used many functions like `plot`, and `linspace`. But you can also define your own functions. To define a new function, use the `def` command. After def follows the name of the function and then between parentheses the arguments of the function and finally a colon. After the colon you indent until you are done with the function. The last line of the function can be `return` followed by what you want to return. For example, consider the following function of x:
#
# $f(x)=cos(x) \qquad x<0$
#
# $f(x)=exp(−x) \qquad x≥0$
#
# Let's implement $f(x)$ in a function called `func`. There is one input argument: **x**.

# %%
def func(x):
    if x < 0:
        f = np.cos(x)
    else:
        f = np.exp(-x)
    return f

# %%
print(func(8))

# %% [markdown]
# Once you define a function in Python, you can call it whenever you want during the session. So we can call it again and yes we don't need to use `print` here because in the definition we told it to return the calculated value of f.

# %%
func(-2)

# %% [markdown]
# If you type
#
# `func(` and then hit [shift-tab]
#
# and wait a split second, the input arguments of the function pop-up in a little window, just like for other functions we already used. You can also provide additional documentation of your function. Put the documentation at the top of the indented block and put it between triple double quotes (`"""`). Run the code below to define a new function `func2` with the additional documentation, then in the code cell below type
#
# `func2(`
#
# and hit [shift][tab] to see the additional documentation. Warning: don't leave a code cell with just `func2(` or `func2()` as you will get an error on [Kernel][Restart & Run All Cells].

# %%
def func(x):
    """First Python function
    written by Student X"""
    if x < 0:
        f = np.cos(x)
    else:
        f = np.exp(-x)
    return f

# %% [markdown]
# **Exercise 1g**
#
# Write a Python function for the following function:
#
# $f(x)=e^{−αx}cos(x)$
#
# The function should take `x` and `alpha` as input arguments and return the function value. Give your function a unique name (if you also call it `func` it will overwrite the `func` function that we defined above). Make a plot of $f(x)$ vs. $x$ for $x$ going from 0 to $10π$ using two different values of $α$: 0.1 and 0.2.

# %%
# your answer here, for the definition of your function

# %%
# your answer here, for plotting







# following lines are there just to add a bit of formatting, you are free to change these
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend();    # to remove the legend error just write __ label=r'$\alpha$=0. ' __ in plt.plot(x,y, __write here__) for both plots
