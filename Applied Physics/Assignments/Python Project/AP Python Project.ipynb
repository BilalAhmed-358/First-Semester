# %% [markdown]
# # Question 01 (Vectors)
# ### What are (a) the x component and (b) the y component of avector in the xy plane if its direction is 250° counterclockwise from the positive direction of the x axis and its magnitude is 7.3 m?

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
magnitude=7.3
angle=math.radians(250)
xcomp= magnitude*math.cos(angle)
ycomp= magnitude*math.sin(angle)
print("The magnitude of x-component is",xcomp,"and the magnitude of the y-component is",ycomp)
X = np.array(0)
Y= np.array(0)
U = np.array(xcomp)
V = np.array(ycomp)
fig, ax = plt.subplots()
a = ax.quiver(X, Y, U, V,color = 'r', units='xy' ,scale=1.5)

A=np.array(xcomp)
B=np.array(0)
Ax=ax.quiver(A,B,color = 'b', units='xy' ,scale=1.5)
C=np.array(0)
D=np.array(ycomp)
Ax=ax.quiver(C,D,color = 'b', units='xy' ,scale=1.5)

plt.grid()

ax.set_aspect('equal')

plt.xlim(-5,5)
plt.ylim(-5,5)
plt.plot()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Vector and its components representation')
# Out:
# The magnitude of x-component is -2.49674704627738 and the magnitude of the y-component is -6.859756131737131
# Text(0.5, 1.0, 'Vector and its components representation')

# %% [markdown]
# # Question 02 (Dot product and Cross Product)
# ## Two vectors are presented as a=3i+5j b=2i+4j. Find a.b

# %%
import matplotlib.pyplot as plt
import numpy as np
A=np.array([3,5])
B=np.array([2,4])
dot=np.dot(A,B)
print("The Dot product of the given vectors is",dot)
a= np.array(3)
b= np.array(5)
c = np.array(2)
d = np.array(4)

fig, ax = plt.subplots()
Vect_1 = ax.quiver(a,b,color = 'r', units='xy' ,scale=1)
Vect_2 = ax.quiver(c,d,color = 'b', units='xy' ,scale=1)
plt.grid()

ax.set_aspect('equal')

plt.xlim(-6,6)
plt.ylim(-6,6)
plt.plot()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Vector representation of Vector A and B')
# Out:
# The Dot product of the given vectors is 26
# Text(0.5, 1.0, 'Vector representation of Vector A and B')

# %% [markdown]
# # Question 03 (Motion in 1D)
# ## The position of an object moving along an x axis is given by x=3t-4t^2+t^3, where x is in meters and t in seconds. Find the position of the object at the following values of t: (a) 4 s (b) 5 s

# %% [markdown]
# ## at t=4s

# %%
import matplotlib.pyplot as plt
import numpy as np
t=4
x=3*t-4*(t**2)+t**3
a= np.array(x)
b= np.array(0)
fig, ax = plt.subplots()
Disp = ax.quiver(a,b,color = 'r', units='xy' ,scale=1)
plt.grid()
print("The position of the object afte 4s is",x,"m")

ax.set_aspect('equal')

plt.xlim(-1,15)
plt.ylim(-1,15)
plt.plot()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Position Vector of Particle')
# Out:
# The position of the object afte 4s is 12 m
# Text(0.5, 1.0, 'Position Vector of Particle')

# %% [markdown]
# ## at t=5s

# %%
import matplotlib.pyplot as plt
import numpy as np
t=5
x=3*t-4*(t**2)+t**3
a= np.array(x)
b= np.array(0)
fig, ax = plt.subplots()
Disp = ax.quiver(a,b,color = 'r', units='xy' ,scale=1)
plt.grid()

ax.set_aspect('equal')
print("The position of the object afte 4s is",x,"m")
plt.xlim(-1,40)
plt.ylim(-1,15)
plt.plot()
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Position Vector of Particle')
# Out:
# The position of the object afte 4s is 40 m
# Text(0.5, 1.0, 'Position Vector of Particle')

# %% [markdown]
# # Question 04 (Motion in 2D)
# ## The floor of a railroad flatcar is loaded with loose crates having a coefficient of static friction of 0.25 with the floor. If the train is initially moving at a speed of 48 km/h, in how short a distance can the train be stopped at constant acceleration without causing the crates to slide over the floor?

# %%
Nu=0.25
Vini=48/3600*1000
Vf=0
acceleration=Nu*9.8
Distance=(Vini**2+Vf**2)/(2*acceleration)
print("The distnace after which the train will stop is",Distance,"m")
# Out:
# The distnace after which the train will stop is 36.281179138321995 m

# %% [markdown]
# # Question 05 (Projectile Motion)
# ## A projectile is fired horizontally from a gun that is 45.0 m above flat ground, emerging from the gun with a speed of 250 m/s. (a) How long does the projectile remain in the air?(b) At what horizontal distance from the firing point does it strike the ground?

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
time=np.arange(0,0.19,0.001)
Viniy=0
Vinix=250
height=45
theta=0
angle=math.radians(theta)
t=np.sqrt((2*height)/9.8)
distance=t*Vinix
print("The projectile remained in the air for",t,"sec\nAnd the distance covered is",distance,"m")
ax.set_aspect('equal')
x = Vinix*time
y=(math.tan(angle)*(x))-(9.8*(x)**2)/(2*(Vinix**2))
plt.plot(x,y,'purple')
plt.title("Trajectory of projectile")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid()
# Out:
# The projectile remained in the air for 3.0304576336566322 sec
# And the distance covered is 757.6144084141581 m

# %% [markdown]
# # Question 06 (Uniform Circular Motion)
# ## An Earth satellite moves in a circular orbit 640 km (uniform circular motion) above Earth’s surface with a period of 98.0 min. What are (a) the speed and (b) the magnitude of the centripetal acceleration of the satellite?

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
radius_of_earth =6.37e6
Total_radius=radius_of_earth+640000
Time_period=98*60
speed=(2*math.pi*Total_radius)/(Time_period)
cent_acc=speed**2/radius_of_earth
print("The speed of the satellite is ",speed,"m/s\nAnd the magnitude of the centripetal acceleration is ",cent_acc,"m/s^2")
circle2 = plt.Circle((0, 0),Total_radius,fc="none",ec='red')
fig, ax = plt.subplots()
ax.add_artist(circle2)
ax.set_aspect('equal')
a= np.array(Total_radius)
b= np.array(0)
Radius = ax.quiver(a,b,color = 'r', units='xy' ,scale=1)
c= np.array((Total_radius))
d= np.array((0))
e=np.array((0))
f=np.array((4e6))
Centripetal_acceleration= ax.quiver(c,d,e,f,color = 'b', units='xy' ,scale=1)
plt.grid()
plt.xlim(-1e7,1e7)
plt.ylim(-1e7,1e7)
plt.title("Orbit and radius of the satellite (in red)\nDirection of velocity(with blue)",fontsize=10)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
fig.savefig('plotcircles.png')
# Out:
# The speed of the satellite is  7490.668197845051 m/s
# And the magnitude of the centripetal acceleration is  8.80849451337633 m/s^2

# %% [markdown]
# # Question 07 (Newton's laws)
# ## Only two horizontal forces act on a 3.0 kg body that can move over a frictionless floor. One force is 9.0 N, acting due east, and the other is 8.0 N, acting 62 degree north of west.What is the magnitude of the body’s acceleration?

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
F1=9
theta1=0
angle1=np.radians(theta1)
F2=8
theta2 =180-62
angle2=np.radians(theta2)
F3x=F1*np.cos(angle1)+F2*np.cos(angle2)
F3y=F1*np.sin(angle1)+F2*np.sin(angle2)
angle3=math.atan(F3y/F3x)
F3=np.sqrt((F3x)**2+(F3y)**2)
mass=3
acceleration=(F3)/mass
print("The magnitude of the body's acceleration is ",angle3,"m/s^2")
a= np.array(F1*np.cos(angle1))
b= np.array(F1*np.sin(angle1))
c = np.array(F2*np.cos(angle2))
d = np.array(F2*np.sin(angle2))
e=np.array(acceleration*np.cos(angle3))
f=np.array(acceleration*np.sin(angle3))
fig, ax = plt.subplots()
F_1 = ax.quiver(a,b,color = 'r', units='xy' ,scale=1)
F_2 = ax.quiver(c,d,color = 'b', units='xy' ,scale=1)
acceleration = ax.quiver(e,f,color = 'purple', units='xy' ,scale=1)
plt.grid()
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.plot()
plt.xlabel('x-axis\n\nFree body diagram',fontsize=12)
plt.ylabel('y-axis',fontsize=12)
plt.title("Free body diagram")
plt.title('Vector representation of Forces acting on the body\nF1 in red\nF2 in blue\ndirection of acceleration in purple')
# Out:
# The magnitude of the body's acceleration is  0.9321564389715663 m/s^2
# Text(0.5, 1.0, 'Vector representation of Forces acting on the body\nF1 in red\nF2 in blue\ndirection of acceleration in purple')

# %% [markdown]
# # Question 08 (Simple Harmonic Motion)
# ## An object undergoing simple harmonic motion takes 0.25 s to travel from one point of zero velocity to the next such point. The distance between those points is 36 cm. Calculate the (a) period, (b) frequency, and (c) amplitude of the motion.

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
time= 0.25
distance=36
Time_period=2*time
frequency=1/Time_period
amplitude=distance/2
print("The time period is",Time_period,"s\nThe frequency is",frequency,"Hz\nThe amplitude is",amplitude,"cm")
time=np.arange(0.001,20,.1)
w=(2*3.142)/time
phs=0
def disp(amplitude,w,time,phs):
    disp=amplitude*np.cos(w*time+phs)
    return disp
plt.title("This is the graph of displacement",fontsize='12')
plt.plot(time,disp(12,15,time,6))
plt.grid()
plt.show()
def vel(amp,w,time,phs):
    vel=amplitude*w*(np.sin(w*time+phs))
    return vel
plt.title("This is the graph of velocity",fontsize='12')
plt.plot(time,vel(6,5,time,.1))
plt.grid()
plt.show()
def acc(amplitude,w,time,phs):
    acc=amplitude*(w**2)*(np.cos(w*time+phs))
    return acc
plt.title("This is the graph of acceleration",fontsize='12')
plt.plot(time, acc(20,30,time,1))
plt.grid()
plt.show()
# Out:
# The time period is 0.5 s
# The frequency is 2.0 Hz
# The amplitude is 18.0 cm

# %% [markdown]
# # Question 09 (Damped Oscillation)
# ## For the damped oscillator system, with m = 250 g, k = 85 N/m, and b = 70 g/s, t=0.34s what is the ratio of the oscillation amplitude at the end of 20 cycles to the initial oscillation amplitude?

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
m=250/1000
k=85
b=70/1000
t=0.34
Amp20=math.exp(-(b*20*t)/(2*m))
Amp1=math.exp(-(b*t)/(2*m))
print("The ratio of oscillation amplitude at the end of 20 cycles to the\
initial oscillation amplitude is",Amp20/Amp1)
# Out:
# The ratio of oscillation amplitude at the end of 20 cycles to theinitial oscillation amplitude is 0.40478468306618554

# %% [markdown]
# # Question 10 (Waves Motion)
# ## If a wave y(x, t) =(6.0 mm) sin(kx + (600 rad/s)t) travels along a string, how much time does any given point on the string take to move between displacements y=+2.0 mm and y=-2.0 mm?

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
amp=6/1000
w=600
fi=0
y1=2/1000
y2=-2/1000
# y1=amp*sin(kx+600*t1)
# 600*t1+kx=asin(y1/amp)
# 600*t1+kx=math.asin(0.002/0.006)
# 600*t1+kx=math.asin(0.002/0.006)      #==>Eq(1)
# y2=amp*sin(kx+600*t2)
# 600*t2+kx=asin(y2/amp)
# 600*t2+kx=math.asin(-0.002/0.006)
# 600*t2+kx=math.asin(-0.002/0.006)     #==>Eq(2)
# #Subtracting Equation 1 and 2
time_difference=((math.asin(0.002/0.006))-(math.asin(-0.002/0.006)))/600
print("The time taken by the wave to reach from y1 to y2 \nis",time_difference,"s")
# Out:
# The time taken by the wave to reach from y1 to y2
# is 0.0011327896981804064 s

# %% [markdown]
# # Question 11 (Electric Forces)
# ## What must be the distance between point charge q1 =26.0 µC and point charge q2=47.0 µC for the electrostatic force between them to have a magnitude of 5.70 N?

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
q1=26e-6
q2=47e-6
F=5.7
k=9e9
r=np.sqrt((k*q1*q2)/(F))
print("The distance between the two charges is",r,"m")
# Out:
# The distance between the two charges is 1.3890549608314735 m

# %% [markdown]
# # Question 12 (Electric Fields)
# ## A charged particle produces an electric field with a magnitude of 2.0 N/C at a point that is 50 cm away from the particle. What is the magnitude of the particle’s charge?

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
E=2
r=50/100
k=9e9
q=(r**2)*E/(k)
print("The magnitude of the charge is",q,"C")
circle2 = plt.Circle((0, 0),.3,fc="blue")
fig, ax = plt.subplots()
ax.add_artist(circle2)
Radius = ax.quiver(5,0,color = 'r', units='xy' ,scale=1)
Radius = ax.quiver(-5,0,color = 'r', units='xy' ,scale=1)
Radius = ax.quiver(0,5,color = 'r', units='xy' ,scale=1)
Radius = ax.quiver(0,-5,color = 'r', units='xy' ,scale=1)
a=np.array((0))
b=np.array((0))
c=np.array((5*math.sin(0.785)))
d=np.array((5*math.sin(0.785)))
Radius = ax.quiver(a,b,c,d,color = 'r', units='xy' ,scale=1)
Radius = ax.quiver(a,b,-c,-d,color = 'r', units='xy' ,scale=1)
Radius = ax.quiver(a,b,-c,d,color = 'r', units='xy' ,scale=1)
Radius = ax.quiver(a,b,c,-d,color = 'r', units='xy' ,scale=1)
plt.grid()
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.title("Electric field around a positive charge",fontsize=10)
plt.xlabel('x-axis')
ax.set_aspect('equal')
plt.ylabel('y-axis')
fig.savefig('plotcircles.png')
# Out:
# The magnitude of the charge is 5.5555555555555553e-11 C

# %% [markdown]
# # Question 13 (Capacitor)
# ## The two metal objects have net charges of +70 pC and -70 pC, which result in a 20 V potential difference between them. a)What is the capacitance of the system? (b) If thecharges are changed to +200 pC and -200 pC, what does the capacitancebecome? (c) What does the potential difference become?

# %%
Q=70
V=20
C=np.divide(Q,V)
print("(A)The Capacitence of the system is",C,"pF")
print("(B)Capacitance is independent of Q it will remain same")
Q=200
V=np.divide(Q,C)
print("(C)The Voltage of the system becomes",V,"Volts")
# Out:
# (A)The Capacitence of the system is 3.5 pF
# (B)Capacitance is independent of Q it will remain same
# (C)The Voltage of the system becomes 57.142857142857146 Volts

# %% [markdown]
# # Question 14 (Electric Current)
# ## During the 4.0 min a 5.0 A current is set up in a wire, how many (a) coulombs and (b) electrons pass through any cross section across the wire’s width?

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
I=5
t=4*60
q=np.multiply(I,t)
electron_num=np.divide(q,1.6e-19)
print("(A)The number of coulumbs that passes throught the wire are",q,"C\n(B)The number of electrons that passed throught the wire are",electron_num)
# Out:
# (A)The number of coulumbs that passes throught the wire are 1200 C
# (B)The number of electrons that passed throught the wire are 7.5e+21

# %% [markdown]
# # Question 15 (Ohm's Law)
# ## Thermal energy is produced in a resistor at a rate of 100 Wwhen the current is 3.00 A.What is the resistance?

# %%
import math
import matplotlib.pyplot as plt
import numpy as n
P=100
I=3
R=np.divide(P,I**2)
print("The resistance of the system is",R,"Ohms")
# Out:
# The resistance of the system is 11.11111111111111 Ohms
