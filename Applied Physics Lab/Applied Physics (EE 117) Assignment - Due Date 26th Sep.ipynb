# %% [markdown]
# # Task 01: Prepare the code of the following two outputs on Jupyter notebook using markdown

# %% [markdown]
# # Task 01 (Part 01):

# %% [markdown]
# ## 2.Review of Literature

# %% [markdown]
# ## 2.1 Water Demand Assessment Techniques

# %% [markdown]
# System water demand is the amount of water that the treatment plant or direct water supply source must produce to meet all community water need (Arunkumar and Nethaji Mariappan 2011).

# %% [markdown]
# ## 2.2 **Water Consevation Strategies**

# %% [markdown]
# ### 2.2.1 Water Efficient Devices

# %% [markdown]
# Behavioural practices and engineering practices are the two water use efficiency practices. The behavioural practices are related to water consumption habits.

# %% [markdown]
# ### 2.2.1.1 _Low Flow showerheads_

# %% [markdown]
# Low flow showerheads installation could save water because of low flow rate

# %% [markdown]
# ### 2.2.1.2 _Faucet Aerators_

# %% [markdown]
# The inexpensive devices that can be fitted in sinks to reduce water use are known as faucet aerators.

# %% [markdown]
# # Task 01 (Part 02):

# %% [markdown]
# ## Groceries:

# %% [markdown]
# 1. Fruit:
#     1. Pears
#     2. Peaches
#     3. Plums
#     4. Apples
#         1. Granny Smith
#         2. Gala
#     5. Oranges
#     6. Berries
#         1. Strawberries
#         2. Blueberries
#         3. Rasphberries
#     7. Bananas
# 2. Bread:
#     1. Whole Wheat
#         1. With oats on crust
#         2. Without oats on crust
#     2. Rye
#     3. White
# 3. Dairy:
#     1. Milk
#         1. Whole
#         2. Skim
#     2. Cheese
#         1. Wisconsin Cheddar
#         2. Pepper Jack

# %% [markdown]
# # Task 02: Make code for the following a table on markdown cell.

# %% [markdown]
# Table: _Projected Sewage Volume of Fully developed DCK_

# %% [markdown]
# | S-No.| Land use Types | Projected Sewage (MGD) |
# |---|---|---|
# |1|Residental|14.84|
# |2|Commercial|6.05|
# |3|Mixed use (Res. Cum Com)|5.92|
# |4|Amenities|2.99|
# ||Total|29.80|

# %% [markdown]
# # Task 03 (Part 01): Make code for (i) Add our own photograph from your system(PC or laptop).

# %% [markdown]
# ![Inspirational%20quote.png](attachment:Inspirational%20quote.png)

# %% [markdown]
# # Task 03 (Part 02): Make code for (ii) Add any image from website.

# %% [markdown]
# ![An image from the website](https://source.unsplash.com/On-ayJ6MaDg)

# %% [markdown]
# # Task 04: Make code for any link of your favorite online course website ( e.g Coursera or Edx or Udemy ).

# %% [markdown]
# [My favorite photoshop course](https://www.udemy.com/course/ultimate-photoshop-training-from-beginner-to-pro/)
